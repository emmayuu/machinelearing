# %%
#1 load data in pandas
import pandas as pd
market = pd.read_csv('/Users/emma/Desktop/ml.csv')
market
# Out:
#          Date  RMinusRf  RmMinusRf
# 0    1/1/2006     -4.59       2.21
# 1    2/1/2006      0.39      -0.31
# 2    3/1/2006      2.36       0.74
# 3    4/1/2006     -1.40       0.84
# 4    5/1/2006      2.99      -3.48
# 5    6/1/2006     -0.88      -0.38
# 6    7/1/2006      4.00       0.11
# 7    8/1/2006      3.54       1.71
# 8    9/1/2006      0.05       2.07
# 9   10/1/2006      3.37       2.75
# 10  11/1/2006     -2.08       1.22
# 11  12/1/2006     -0.23       0.86
# 12   1/1/2007      0.78       1.00
# 13   2/1/2007     -5.66      -2.61
# 14   3/1/2007     -4.67       0.57
# 15   4/1/2007      6.15       3.92
# 16   5/1/2007     -1.21       2.86
# 17   6/1/2007     -2.98      -2.15
# 18   7/1/2007     -2.22      -3.59
# 19   8/1/2007      2.48       0.94
# 20   9/1/2007      6.02       3.27
# 21  10/1/2007     -1.12       1.17
# 22  11/1/2007      4.29      -4.71
# 23  12/1/2007     -1.76      -1.10
# 24   1/1/2008     -5.56      -6.34
# 25   2/1/2008     -1.41      -3.66
# ...

# %%
#2.  Writing an apply function that transforms a column

# %%
def applyRmMinusRf(df):
    df['colnew'] = RmMinusRf(df)
    return(df)

df = df.groupby('Date').apply(applyRmMinusRf)
df
# Out:
#          Date  RMinusRf  RmMinusRf  colnew
# 0    1/1/2006     -4.59       2.21   -6.80
# 1    2/1/2006      0.39      -0.31    0.70
# 2    3/1/2006      2.36       0.74    1.62
# 3    4/1/2006     -1.40       0.84   -2.24
# 4    5/1/2006      2.99      -3.48    6.47
# 5    6/1/2006     -0.88      -0.38   -0.50
# 6    7/1/2006      4.00       0.11    3.89
# 7    8/1/2006      3.54       1.71    1.83
# 8    9/1/2006      0.05       2.07   -2.02
# 9   10/1/2006      3.37       2.75    0.62
# 10  11/1/2006     -2.08       1.22   -3.30
# 11  12/1/2006     -0.23       0.86   -1.09
# 12   1/1/2007      0.78       1.00   -0.22
# 13   2/1/2007     -5.66      -2.61   -3.05
# 14   3/1/2007     -4.67       0.57   -5.24
# 15   4/1/2007      6.15       3.92    2.23
# 16   5/1/2007     -1.21       2.86   -4.07
# 17   6/1/2007     -2.98      -2.15   -0.83
# 18   7/1/2007     -2.22      -3.59    1.37
# 19   8/1/2007      2.48       0.94    1.54
# 20   9/1/2007      6.02       3.27    2.75
# ...

# %%
#3.  A basic Data Visualization using Seaborn or Plotly library or Matplotlib
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)
market.plot(kind="scatter", x="RMinusRf", y="RmMinusRf")
sns.jointplot(x="RMinusRf", y="RmMinusRf", data=market, size=2)

# %%
#4.  Some type of Machine Learning technique on the data
#linear regression
import numpy as np
import pandas as pd
from numpy.linalg import inv
from numpy import dot
market = pd.read_csv('/Users/emma/Desktop/ml.csv')

temp = market.iloc[:, 1:4]
temp['x0'] = 1
X = temp.iloc[:, [1,2]]
Y = market.iloc[:, 2]
Y = Y.reshape(len(market), 1)
theta_n = dot(dot(inv(dot(X.T, X)), X.T), Y) # theta = (X'X)^(-1)X'Y
theta_n
# Out:
# /Users/emma/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   del sys.path[0]
# array([[  1.00000000e+00],
#        [ -3.33066907e-16]])

# %%
#5.  A script or Makefile that runs https://github.com/computationalmodelling/nbval (Links to an external site.)
import requests
url = "https://github.com/computationalmodelling/nbval"
content = requests.get(url).content
content
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://assets-cdn.github.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-f27d807afb610bf126cbfb9ce429438a328e012239e5a77fc8152b794553dfc0.css" media="all" rel="stylesheet" />\n  <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-1babc1bd6327bf889358e4d39d284da9b84127f3154b925b3f2804d77dc80aea.css" media="all" rel="stylesheet" />\n  \n  \n  <l
# ...
